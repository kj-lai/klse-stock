# %% [markdown]
# ## First Stage Filter
#
# - nYear  >= 5 years
# - ROI    >= 8 %
# - ROE    >= 8 %
# - EY     >= 6 %
#
#
# ## Default Parameter
#
# - ROI    >= 10 %
# - ROE    >= 15 %
# - EPS GR >= 15 %
# - D/E    <= 0.5
# - P/E    <= P/E mid
# - P/E    =  6.66 - 12.5
# - Ey     =  8 % - 15 %

# %%
val1, val2, fig1, fig2, fig3 = show_tables(3034)
# Out:
# ----- Stock Details for 3034:  -----
# <<<  This Stock did not pass Stage 4 filter.  >>>
#
# ----- Past 10 Year Financials -----
#    Year Year End Shares   Price   NTA    ROI    ROE     NP NP Margin     EY  \
# 2    Y1  2018-12  2,490  9.9800  2.96   4.61  17.91  1,146     18.34   4.61
# 3    Y2  2017-12  2,490  9.8500  2.46   4.50  19.62  1,104     20.87   4.47
# 4    Y3  2016-12  2,490  9.5500  2.36   4.21  20.57  1,001     20.46   4.40
# 5    Y4  2015-12  2,313  8.8600  2.00   4.43  22.17    908     20.68   4.40
# 6    Y5  2014-12  2,197  6.4800  1.91   5.29  20.63    753     20.00   5.25
# 7    Y6  2013-12  2,113  4.6800  1.69   5.95  17.42    588     16.87   5.98
# 8    Y7  2012-12  2,162  3.0100  1.61   6.50  12.63    423     10.68   6.64
# 9    Y8  2011-12  1,993  1.7400  1.18  10.84  12.78    376     10.64  10.92
# 10   Y9  2010-12  1,952  1.5900  1.20  10.41  13.13    323     11.90  10.69
# 11  Y10  2009-12  1,952  2.3600     —   2.17   4.32    100      4.07   2.12
#
#       P/E   EPS  EPS GR EPS GR 5Y avg EPS GR 10Y avg    DY   DPS Div Payout
# 2   21.70  0.46    3.77         10.57          11.08  3.51  0.35       77.2
# 3   22.39  0.44    4.67         17.80          23.89  3.55  0.35       84.2
# 4   22.74  0.42    7.84         17.58          26.11  3.66  0.35       59.6
# 5   22.72  0.39   14.52         18.86              —  2.26  0.20       56.7
# 6   19.06  0.34   23.20         46.19              —  5.09  0.33       54.8
# 7   16.71  0.28   42.40         11.59              —  2.99  0.14       52.1
# 8   15.05  0.20    3.71         30.29              —  2.99  0.09       47.1
# 9    9.16  0.19   13.84         35.26              —  5.75  0.10       33.1
# 10   9.35  0.17  222.32             —              —  3.14  0.05       33.1
# 11  47.20  0.05       —             —              —  1.27  0.03          —
#    Revenue Revenue GR Revenue GR 5Y avg Revenue GR 10Y avg    OCF  OCF GR  \
# 2    6,247      18.11             12.37               7.03   -448       —
# 3    5,289       8.12              5.96              11.82   -856       —
# 4    4,892      11.34              6.73              12.86    626       —
# 5    4,393      16.59             10.11                  —   -451       —
# 6    3,768       8.07              8.86                  —    297  312.00
# 7    3,487     -11.93              1.95                  —     72  -89.42
# 8    3,959      12.10             18.00                  —    682       —
# 9    3,531      30.08             19.34                  —   -365       —
# 10   2,715      10.17                 —                  —    109  -90.62
# 11   2,464          —                 —                  —  1,161       —
#
#      D/E
# 2   0.40
# 3   0.28
# 4   0.35
# 5   0.44
# 6   0.18
# 7   0.28
# 8   0.29
# 9   0.42
# 10  0.31
# 11  0.30
# ----- Plot Graphs -----

# %%
val1, val2, fig1, fig2, fig3 = show_tables(4731)
# Out:
# ----- Stock Details for 4731: SCIENTEX BERHAD -----
#                 name                        category  price   NTA  52w low  \
# 101  SCIENTEX BERHAD  Industrial Products & Services   7.48  4.57     5.96
#
#      52w high market cap      Annual  nYear  nMerge  nSplit
# 101      9.87   3,858.8M  2019-07-01     10       0       0
#      code    ROE   P/E    EPS    EY   DPS    DY   ROI  ROI avg  ROI std  \
# 101  4731  16.32  10.0  74.58  9.97  20.0  2.67  7.92     6.57     1.52
#
#      NPM avg  NPM std  EPS avg  EPS std  EPS GR avg  EPS GR std  \
# 101     9.78     0.84     0.38     0.18       23.99       19.12
#
#      EPS GR 5Y avg  EPS GR 10Y avg
# 101          14.75           22.59
#      EY avg  EY std  ROE avg  ROE std  P/E mid  P/E avg  P/E std  DPS avg  \
# 101     6.6    1.53     18.6     2.23    17.52    16.07     4.02     0.11
#
#      DPS std  DPayout avg  DPayout std  DY avg  DY std  D/E avg  D/E std
# 101     0.05         29.1         3.36    2.01     0.6     0.12     0.08
#      Operating CF GR avg  Operating CF GR std  Revenue GR avg  Revenue GR std  \
# 101                27.26                 35.1            20.8           10.69
#
#      Revenue GR 5Y avg  Revenue GR 10Y avg  intrinsic  price_A  price_B
# 101              15.34               20.34      26.52    19.89     7.25
# ----- Past 10 Year Financials -----
#    Year Year End Shares    Price   NTA   ROI    ROE   NP NP Margin    EY  \
# 2    Y1  2019-07    501   8.4200  4.17  7.92  16.73  334     10.28  7.96
# 3    Y2  2018-07    486   7.9000  3.51  7.55  17.57  290     11.04  7.34
# 4    Y3  2017-07    467   8.6600  2.77  6.33  18.88  256     10.65  6.35
# 5    Y4  2016-07    455  12.7000  2.49  4.17  22.75  241     10.95  4.17
# 6    Y5  2015-07    449   7.1000  1.89  4.96  19.12  158      8.78  4.93
# 7    Y6  2014-07    442   5.6900  1.55  5.88  22.13  148      9.34  5.98
# 8    Y7  2013-07    432   5.2900  1.32  4.81  19.11  110      8.99  4.91
# 9    Y8  2012-07    430   2.4000  1.14  8.14  16.90   84      9.52  8.33
# 10   Y9  2011-07    430   2.5800  0.90  6.94  17.52   77      9.61  6.98
# 11  Y10  2010-07    431   1.5500  0.82  8.98  15.28   60      8.68  9.03
#
#       P/E   EPS EPS GR EPS GR 5Y avg EPS GR 10Y avg    DY   DPS Div Payout
# 2   12.57  0.67  11.10         14.75          22.59  2.38  0.20       34.0
# 3   13.62  0.58   9.09         18.66          17.39  2.53  0.20       28.2
# 4   15.75  0.55   3.77         23.05          19.65  1.85  0.16       31.0
# 5   23.96  0.53  51.43         24.18          21.60  1.02  0.13       21.2
# 6   20.29  0.35   4.48         20.11              —  1.55  0.11       29.7
# 7   16.74  0.34  31.37         30.97              —  1.58  0.09       27.2
# 8   20.35  0.26  30.77         16.14              —  1.32  0.07       29.1
# 9   12.00  0.20   8.65         16.35              —  2.92  0.07       33.3
# 10  14.33  0.18  28.19         19.07              —  2.33  0.06       28.6
# 11  11.07  0.14  61.03             —              —  2.58  0.04       28.7
#    Revenue Revenue GR Revenue GR 5Y avg Revenue GR 10Y avg Operating CF  \
# 2    3,246      23.61             15.34              20.34          557
# 3    2,626       9.31             16.43              14.87          392
# 4    2,402       9.19             22.22              14.63          323
# 5    2,200      22.16             22.30              14.14          380
# 6    1,801      13.28             20.98                  —          192
# 7    1,590      29.56             25.55                  —          154
# 8    1,227      39.28             13.32                  —          213
# 9      881       9.58              7.52                  —          129
# 10     804      15.72              6.52                  —          111
# 11     695      36.31                 —                  —           78
#
#    Operating CF GR   D/E
# 2            41.93  0.12
# 3            21.55  0.18
# 4           -15.11  0.11
# 5            98.31  0.20
# 6            24.69  0.08
# 7           -27.82  0.11
# 8            64.63  0.27
# 9            16.67  0.01
# 10           41.98  0.02
# 11            5.77  0.06
# ----- Plot Graphs -----

# %%
val1, val2, fig1, fig2, fig3 = show_tables(5271)
# Out:
# ----- Stock Details for 5271: PECCA GROUP BERHAD -----
#                   name                        category  price    NTA  52w low  \
# 90  PECCA GROUP BERHAD  Industrial Products & Services  0.745  0.913    0.675
#
#     52w high market cap      Annual  nYear  nMerge  nSplit
# 90       1.3     140.1M  2019-06-01      5       0       0
#     code   ROE  P/E  EPS     EY  DPS    DY   ROI  ROI avg  ROI std  NPM avg  \
# 90  5271  9.42  9.0  8.6  11.54  6.0  8.05  7.96     6.34     1.07    11.82
#
#     NPM std  EPS avg  EPS std  EPS GR avg  EPS GR std  EPS GR 5Y avg  \
# 90     1.58     0.09     0.02       -2.22       38.55            0.0
#
#     EPS GR 10Y avg
# 90             0.0
#     EY avg  EY std  ROE avg  ROE std  P/E mid  P/E avg  P/E std  DPS avg  \
# 90    6.47    1.02    12.85     6.76    10.06     12.7     6.79     0.03
#
#     DPS std  DPayout avg  DPayout std  DY avg  DY std  D/E avg  D/E std
# 90     0.02        66.97        23.92    3.66    1.86     0.16      0.0
#     Operating CF GR avg  Operating CF GR std  Revenue GR avg  Revenue GR std  \
# 90                24.63                74.73            0.77            9.36
#
#     Revenue GR 5Y avg  Revenue GR 10Y avg  intrinsic  price_A  price_B
# 90                0.0                 0.0       6.65     4.99     0.88
# ----- Past 10 Year Financials -----
#    Year Year End Shares   Price   NTA   ROI    ROE  NP NP Margin    EY    P/E  \
# 2    Y1  2019-06    184  1.1600  0.91  7.96  10.22  17     12.65  7.76  12.89
# 3    Y2  2018-06    186  0.8700  0.88  6.18   6.32  10      9.07  6.90  14.50
# 4    Y3  2017-06    188  1.6100  0.86  4.96   9.16  15     12.02  4.97  20.12
# 5    Y4  2016-06    150  1.6000     —  6.25  12.82  15     11.51  6.25  16.00
# 6    Y5  2015-06    140  0.0000     —  0.00  25.71  18     13.85  0.00   0.00
# 7    Y6  2014-06      —       —     —  0.00      —   —         —  0.00   0.00
# 8    Y7  2013-06      —       —     —  0.00      —   —         —  0.00   0.00
# 9    Y8  2012-06      —       —     —  0.00      —   —         —  0.00   0.00
# 10   Y9  2011-06      —       —     —  0.00      —   —         —  0.00   0.00
# 11  Y10  2010-06      —       —     —  0.00      —   —         —  0.00   0.00
#
#      EPS  EPS GR EPS GR 5Y avg EPS GR 10Y avg    DY   DPS Div Payout
# 2   0.09   64.25             —              —  5.17  0.06       33.8
# 3   0.06  -29.45             —              —  5.75  0.05       89.3
# 4   0.08  -19.23             —              —  2.48  0.04       77.8
# 5   0.10  -24.45             —              —  1.25  0.02          —
# 6   0.13       —             —              —  0.00     —          —
# 7      —       —             —              —  0.00     —          —
# 8      —       —             —              —  0.00     —          —
# 9      —       —             —              —  0.00     —          —
# 10     —       —             —              —  0.00     —          —
# 11     —       —             —              —  0.00     —          —
#    Revenue Revenue GR Revenue GR 5Y avg Revenue GR 10Y avg Operating CF  \
# 2      131      16.60                 —                  —           12
# 3      113      -7.77                 —                  —           17
# 4      122      -3.27                 —                  —           15
# 5      126      -2.50                 —                  —           23
# 6      130          —                 —                  —            9
# 7        —          —                 —                  —            —
# 8        —          —                 —                  —            —
# 9        —          —                 —                  —            —
# 10       —          —                 —                  —            —
# 11       —          —                 —                  —            —
#
#    Operating CF GR   D/E
# 2           -29.97     —
# 3            13.79     —
# 4           -35.10     —
# 5           149.81     —
# 6                —  0.16
# 7                —     —
# 8                —     —
# 9                —     —
# 10               —     —
# 11               —     —
# ----- Plot Graphs -----

# %%
val1, val2, fig1, fig2, fig3 = show_tables(5181)
# Out:
# ----- Stock Details for 5181: SIG GASES BERHAD -----
#                 name                        category  price   NTA  52w low  \
# 94  SIG GASES BERHAD  Industrial Products & Services  0.405  0.55     0.36
#
#     52w high market cap      Annual  nYear  nMerge  nSplit
# 94      0.46      75.9M  2018-12-01     10       0       0
#     code    ROE  P/E    EPS      EY   DPS      DY   ROI  ROI avg  ROI std  \
# 94  5181  77.51  1.0  42.63  105.26  55.7  137.53  6.57     5.26      2.5
#
#     NPM avg  NPM std  EPS avg  EPS std  EPS GR avg  EPS GR std  EPS GR 5Y avg  \
# 94     8.17     3.57     0.03     0.02        14.6       96.32           9.49
#
#     EPS GR 10Y avg  EY avg
# 94             0.0    5.39
#     EY std  ROE avg  ROE std  P/E mid  P/E avg  P/E std  DPS avg  DPS std  \
# 94    2.32     5.97      3.4     25.6    22.88    10.43     0.01      0.0
#
#     DPayout avg  DPayout std  DY avg  DY std  D/E avg  D/E std
# 94         31.5        14.47    1.43    0.85     0.11     0.06
#     Operating CF GR avg  Operating CF GR std  Revenue GR avg  Revenue GR std  \
# 94                61.58                196.7             4.3            5.95
#
#     Revenue GR 5Y avg  Revenue GR 10Y avg  intrinsic  price_A  price_B
# 94               4.48                 0.0        1.8     1.35     0.39
# ----- Past 10 Year Financials -----
#    Year Year End Shares   Price   NTA   ROI    ROE  NP NP Margin    EY    P/E  \
# 2    Y1  2018-12    188  0.4050  0.68  6.57   3.96   5      6.38  7.41  13.50
# 3    Y2  2017-12    188  0.8100  0.66  2.63   3.41   4      5.57  2.47  40.50
# 4    Y3  2016-12    188  1.0800  0.65  2.96   5.19   6      8.29  2.78  36.00
# 5    Y4  2015-12    188  0.4150  0.64  7.69   5.49   6      8.45  7.23  13.83
# 6    Y5  2014-12    188  0.5350  0.53  9.94   9.63  10     15.18  9.35  10.70
# 7    Y6  2013-12    156  0.4600  0.58  4.18   2.90   3      4.20  4.35  23.00
# 8    Y7  2012-12    156  0.6000  0.58  3.21   3.75   3      5.29  3.33  30.00
# 9    Y8  2011-12    156  0.6500  0.54  1.97   2.88   2      4.48  3.08  32.50
# 10   Y9  2010-12    122  0.7100  0.54  6.93   8.80   6     10.87  7.04  14.20
# 11  Y10  2009-12    105  1.0200     —  6.54  13.64   7     13.03  6.86  14.57
#
#      EPS  EPS GR EPS GR 5Y avg EPS GR 10Y avg    DY   DPS Div Payout
# 2   0.03   18.14          9.49              —  2.47  0.01       36.9
# 3   0.02  -32.54          1.48              —  1.23  0.01       35.9
# 4   0.03   -1.76         16.62              —  0.93  0.01       54.8
# 5   0.03  -46.21         -7.03              —  2.41  0.01       13.4
# 6   0.05  273.61         -1.30              —  1.87  0.01       10.7
# 7   0.02  -19.18             —              —  2.17  0.01       41.4
# 8   0.02   35.19             —              —  1.67  0.01       27.4
# 9   0.02  -68.36             —              —  1.54  0.01          —
# 10  0.05  -27.48             —              —  0.00     —          —
# 11  0.07       —             —              —  0.00     —          —
#    Revenue Revenue GR Revenue GR 5Y avg Revenue GR 10Y avg Operating CF  \
# 2       79       3.36              4.48                  —            8
# 3       76       0.25              4.12                  —           12
# 4       76       0.17              6.88                  —            7
# 5       76      15.82              6.50                  —            1
# 6       65       3.57              3.68                  —            8
# 7       63       1.58                 —                  —            6
# 8       62      14.29                 —                  —           10
# 9       54      -1.63                 —                  —           11
# 10      55       1.27                 —                  —            6
# 11      55          —                 —                  —           13
#
#    Operating CF GR   D/E
# 2           -36.21  0.08
# 3            77.15  0.09
# 4           597.62  0.05
# 5           -87.90  0.02
# 6            27.01  0.09
# 7           -35.92  0.14
# 8           -10.30  0.19
# 9            73.91  0.12
# 10          -51.18  0.07
# 11               —  0.22
# ----- Plot Graphs -----

# %%
val1, val2, fig1, fig2, fig3 = show_tables(5168)
# Out:
# ----- Stock Details for 5168: HARTALEGA HOLDINGS BERHAD -----
#                           name     category  price   NTA  52w low  52w high  \
# 115  HARTALEGA HOLDINGS BERHAD  Health Care   7.04  0.73     4.62       7.1
#
#     market cap      Annual  nYear  nMerge  nSplit
# 115  23,819.2M  2019-03-01     10       0       0
#      code    ROE   P/E    EPS    EY  DPS    DY   ROI  ROI avg  ROI std  \
# 115  5168  16.62  58.0  12.13  1.72  8.2  1.16  2.91     1.49     0.65
#
#      NPM avg  NPM std  EPS avg  EPS std  EPS GR avg  EPS GR std  \
# 115    20.15     3.45     0.08     0.03        20.1       46.48
#
#      EPS GR 5Y avg  EPS GR 10Y avg  EY avg
# 115          12.33            16.6    1.54
#      EY std  ROE avg  ROE std  P/E mid  P/E avg  P/E std  DPS avg  DPS std  \
# 115    0.66    28.96    10.34    84.84    77.84    33.03     0.04     0.02
#
#      DPayout avg  DPayout std  DY avg  DY std  D/E avg  D/E std
# 115        48.42        14.58    0.69    0.42     0.07     0.04
#      Operating CF GR avg  Operating CF GR std  Revenue GR avg  Revenue GR std  \
# 115                19.21                26.78           19.86           10.02
#
#      Revenue GR 5Y avg  Revenue GR 10Y avg  intrinsic  price_A  price_B
# 115              20.62               20.36      31.18    23.38     5.44
# ----- Past 10 Year Financials -----
#    Year Year End Shares   Price   NTA   ROI    ROE   NP NP Margin    EY  \
# 2    Y1  2019-03  3,372  4.6300  0.66  2.91  21.42  455     16.10  3.02
# 3    Y2  2018-03  3,361  6.0500  0.58  2.16  23.88  439     18.25  2.15
# 4    Y3  2017-03  3,302  4.9600  0.49  1.73  17.78  283     15.53  1.81
# 5    Y4  2016-03  3,304  4.8500  0.45  1.60  18.58  257     17.18  1.65
# 6    Y5  2015-03  3,127  8.6700  0.37  0.77  18.97  210     18.30  0.81
# 7    Y6  2014-03  3,084  6.8500  0.31  1.10  27.29  233     21.03  1.17
# 8    Y7  2013-03  2,968  4.9400  0.25  1.59  33.74  233     22.61  1.62
# 9    Y8  2012-03  3,513  6.6200  0.20  0.86  36.16  201     21.63  0.91
# 10   Y9  2011-03  2,915  4.5400  0.17  1.44  44.85  190     25.89  1.54
# 11  Y10  2010-03  2,908  6.8300     —  0.72  46.97  143     24.99  0.73
#
#        P/E   EPS  EPS GR EPS GR 5Y avg EPS GR 10Y avg    DY   DPS Div Payout
# 2    33.07  0.14    3.37         12.33          16.60  1.73  0.08       59.2
# 3    46.54  0.13   52.39         10.69          17.24  0.99  0.06       40.5
# 4    55.11  0.09   10.01         20.02          22.88  0.81  0.04       51.9
# 5    60.62  0.08   16.53          3.60          30.71  0.82  0.04       45.4
# 6   123.86  0.07  -11.46          6.35          33.41  0.35  0.03       54.1
# 7    85.62  0.08   -3.94         21.04              —  0.58  0.04       45.1
# 8    61.75  0.08  128.41         24.18              —  0.61  0.03       79.8
# 9   110.33  0.06  -47.29         26.35              —  0.45  0.03       29.9
# 10   64.86  0.07   32.84         71.89              —  0.44  0.02       29.9
# 11  136.60  0.05       —             —              —  0.15  0.01          —
#    Revenue Revenue GR Revenue GR 5Y avg Revenue GR 10Y avg Operating CF  \
# 2    2,827      17.52             20.62              20.36          627
# 3    2,406      32.04             18.44                  —          404
# 4    1,822      21.59             14.37              24.43          337
# 5    1,498      30.75             15.31              27.32          239
# 6    1,146       3.51             14.91              28.88          207
# 7    1,107       7.27             20.09                  —          249
# 8    1,032      10.84                 —                  —          318
# 9      931      26.69             37.43                  —          200
# 10     735      28.51             43.10                  —          185
# 11     572          —                 —                  —          164
#
#    Operating CF GR   D/E
# 2            55.32  0.09
# 3            19.95  0.06
# 4            40.61  0.10
# 5            15.96  0.14
# 6           -17.01     —
# 7           -21.64     —
# 8            58.51  0.01
# 9             8.40  0.02
# 10           12.75  0.05
# 11               —  0.08
# ----- Plot Graphs -----

# %%
val1, val2, fig1, fig2, fig3 = show_tables(5250)
# Out:
# ----- Stock Details for 5250: 7-ELEVEN MALAYSIA HOLDINGS BERHAD -----
#                                   name                      category  price  \
# 151  7-ELEVEN MALAYSIA HOLDINGS BERHAD  Consumer Products & Services   1.36
#
#         NTA  52w low  52w high market cap      Annual  nYear  nMerge  nSplit
# 151  0.0893     1.21      1.56   1,677.4M  2018-12-01      9       0       0
#      code    ROE   P/E   EPS    EY  DPS    DY   ROI  ROI avg  ROI std  \
# 151  5250  49.05  31.0  4.38  3.22  2.4  1.76  3.12     2.79     0.55
#
#      NPM avg  NPM std  EPS avg  EPS std  EPS GR avg  EPS GR std  \
# 151      2.5     0.37     0.03     0.01       10.98       17.26
#
#      EPS GR 5Y avg  EPS GR 10Y avg  EY avg
# 151           5.38             0.0    2.58
#      EY std  ROE avg  ROE std  P/E mid  P/E avg  P/E std  DPS avg  DPS std  \
# 151     0.6    43.71    20.03     37.5    28.12     23.3     0.01     0.01
#
#      DPayout avg  DPayout std  DY avg  DY std  D/E avg  D/E std
# 151        54.22         3.82    1.02    0.77     0.29     0.25
#      Operating CF GR avg  Operating CF GR std  Revenue GR avg  Revenue GR std  \
# 151                23.18                74.95            6.82            3.63
#
#      Revenue GR 5Y avg  Revenue GR 10Y avg  intrinsic  price_A  price_B
# 151                5.8                 0.0       7.76     5.82     1.33
# ----- Past 10 Year Financials -----
#    Year Year End Shares   Price   NTA   ROI    ROE  NP NP Margin    EY    P/E  \
# 2    Y1  2018-12  1,143  1.4300  0.07  3.12  61.69  51      2.31  2.80  35.75
# 3    Y2  2017-12  1,150  1.5000  0.05  2.90  91.75  50      2.29  2.67  37.50
# 4    Y3  2016-12  1,200  1.5400  0.07  2.81  50.81  52      2.48  2.60  38.50
# 5    Y4  2015-12  1,269  1.4200  0.15  3.11  27.46  56      2.78  2.82  35.50
# 6    Y5  2014-12  1,278  1.5400  0.17  3.20  31.49  63      3.33  3.25  30.80
# 7    Y6  2013-12  1,841  1.5000     —  1.59  29.01  44      2.64  1.33  75.00
# 8    Y7  2012-12  1,278  0.0000     —  0.00  33.97  40      2.56  0.00   0.00
# 9    Y8  2011-12  1,278       —     —  0.00  33.55  30      2.06  0.00   0.00
# 10   Y9  2010-12  1,278       —     —  0.00  33.68  27      2.08  0.00   0.00
# 11  Y10  2009-12      —       —     —  0.00      —   —         —  0.00   0.00
#
#      EPS  EPS GR EPS GR 5Y avg EPS GR 10Y avg    DY   DPS Div Payout
# 2   0.04    3.02          5.38              —  2.10  0.03       55.4
# 3   0.04    0.22          6.56              —  1.33  0.02       58.4
# 4   0.04   -1.10         12.98              —  1.30  0.02       48.0
# 5   0.04  -11.03         15.51              —  1.41  0.02       55.1
# 6   0.05   43.02             —              —  0.00     —          —
# 7   0.02    8.94             —              —  0.00     —          —
# 8   0.03   34.29             —              —  0.00     —          —
# 9   0.02   10.47             —              —  0.00     —          —
# 10  0.02       —             —              —  0.00     —          —
# 11     —       —             —              —  0.00     —          —
#    Revenue Revenue GR Revenue GR 5Y avg Revenue GR 10Y avg Operating CF  \
# 2    2,217       1.37              5.80                  —            —
# 3    2,187       3.98              6.73                  —            —
# 4    2,103       4.84              7.54                  —            —
# 5    2,006       5.98              8.84                  —            —
# 6    1,893      13.19                 —                  —            —
# 7    1,672       5.91                 —                  —            —
# 8    1,579       7.98                 —                  —            —
# 9    1,462      11.32                 —                  —            —
# 10   1,314          —                 —                  —            —
# 11       —          —                 —                  —            —
#
#    Operating CF GR   D/E
# 2            68.05  0.48
# 3           -32.94  0.57
# 4           -42.34  0.72
# 5            28.63     —
# 6           -47.23  0.01
# 7           180.27  0.04
# 8           -37.87  0.07
# 9            68.91  0.17
# 10               —  0.24
# 11               —     —
# ----- Plot Graphs -----

# %%
val1, val2, fig1, fig2, fig3 = show_tables(9296)
# Out:
# ----- Stock Details for 9296:  -----
# <<<  This Stock did not pass Stage 4 filter.  >>>
#
# ----- Past 10 Year Financials -----
#    Year Year End Shares   Price    NTA     ROI    ROE   NP NP Margin      EY  \
# 2    Y1  2019-03    342  1.6300   1.64   17.22  17.33   96     36.38   17.18
# 3    Y2  2018-03    341  1.2300   1.39   21.22  18.46   89     36.06   21.14
# 4    Y3  2017-03    331  1.7800  29.62   13.41  17.59   79     35.35   13.48
# 5    Y4  2016-03    321  0.2850   1.38   43.72   7.74   40     24.37   42.11
# 6    Y5  2015-03    296  0.3150   2.01   38.61   4.45   36     20.44   28.57
# 7    Y6  2014-03    292  0.2800   2.16   15.90   0.48   13      2.40    3.57
# 8    Y7  2013-03    333  0.2700   2.34   11.12   1.62   10      5.79   11.11
# 9    Y8  2012-03    293  0.3200   1.75  107.72  20.46  101     44.09  109.38
# 10   Y9  2011-03    293  0.3600   1.53   98.60  24.04  104     49.53   97.22
# 11  Y10  2010-03    284  0.4400      —   64.82  22.62   81     40.55   65.91
#
#       P/E   EPS  EPS GR EPS GR 5Y avg EPS GR 10Y avg     DY   DPS Div Payout
# 2    5.82  0.28    7.58         91.69           1.54   4.91  0.08       39.6
# 3    4.73  0.26    9.07         54.83           1.99   4.88  0.06       11.7
# 4    7.42  0.24   93.34         -7.16          -1.12   2.25  0.04       17.8
# 5    2.38  0.12   35.68        -18.69           1.45  21.05  0.06       43.4
# 6    3.50  0.09  740.74        -20.91              —  19.05  0.06       56.6
# 7   28.00  0.01  -63.01        -46.22              —  21.43  0.06          —
# 8    9.00  0.03  -91.54        -32.82              —  14.81  0.04       22.2
# 9    0.91  0.35   -0.38          5.31              —  12.50  0.04       13.5
# 10   1.03  0.35   18.18         26.58              —  13.89  0.05       13.5
# 11   1.52  0.29       —             —              —   6.82  0.03          —
#    Revenue Revenue GR Revenue GR 5Y avg Revenue GR 10Y avg Operating CF  \
# 2      263       6.78             15.05               4.42            9
# 3      246      10.11              7.94              10.01          -38
# 4      223      37.53             -0.57               8.76          -99
# 5      162      23.78             -5.06              11.96         -140
# 6      131       0.71             -8.09                  —         -111
# 7      130     -22.39             -5.23                  —           -5
# 8      168     -26.98             12.11                  —           42
# 9      230       9.20             18.97                  —          160
# 10     210       5.25             32.03                  —           73
# 11     200          —                 —                  —          -60
#
#    Operating CF GR   D/E
# 2                —  1.76
# 3                —  1.89
# 4                —  1.43
# 5                —  1.12
# 6                —  0.59
# 7                —  0.57
# 8           -73.92  0.77
# 9           118.73  0.85
# 10               —  1.65
# 11               —  1.68
# ----- Plot Graphs -----

# %%
val1, val2, fig1, fig2, fig3 = show_tables(6963)
# Out:
# ----- Stock Details for 6963: V.S. INDUSTRY BERHAD -----
#                     name                        category  price   NTA  \
# 86  V.S. INDUSTRY BERHAD  Industrial Products & Services   0.78  0.91
#
#     52w low  52w high market cap      Annual  nYear  nMerge  nSplit
# 86      0.6      1.52   1,453.9M  2019-07-01     10       0       1
#     code   ROE  P/E   EPS     EY  DPS    DY   ROI  ROI avg  ROI std  NPM avg  \
# 86  6963  9.49  9.0  8.64  11.08  4.4  5.64  7.64     3.56      2.0     4.07
#
#     NPM std  EPS avg  EPS std  EPS GR avg  EPS GR std  EPS GR 5Y avg  \
# 86     1.22     0.06     0.03       56.36      108.52          14.22
#
#     EPS GR 10Y avg  EY avg
# 86           34.74    3.56
#     EY std  ROE avg  ROE std  P/E mid  P/E avg  P/E std  DPS avg  DPS std  \
# 86    2.07     11.8     3.95    45.42    39.66    21.65     0.02     0.01
#
#     DPayout avg  DPayout std  DY avg  DY std  D/E avg  D/E std
# 86        57.92        43.32    1.49    1.07     0.13     0.08
#     Operating CF GR avg  Operating CF GR std  Revenue GR avg  Revenue GR std  \
# 86                 41.5                84.28            19.8           17.47
#
#     Revenue GR 5Y avg  Revenue GR 10Y avg  intrinsic  price_A  price_B
# 86              18.33               18.56       1.95     1.46      0.9
# ----- Past 10 Year Financials -----
#    Year Year End Shares   Price   NTA   ROI    ROE   NP NP Margin    EY  \
# 2    Y1  2019-07  1,800  1.2000  0.84  7.64  10.92  165      4.16  7.50
# 3    Y2  2018-07  1,760  1.6800  0.74  5.11  12.16  151      3.69  5.36
# 4    Y3  2017-07  1,581  2.2000  0.68  4.49  16.14  156      4.76  4.55
# 5    Y4  2016-07  1,522  1.3200  0.58  5.87  14.23  118      5.42  6.06
# 6    Y5  2015-07  1,344  6.3500  0.44  1.56  20.37  133      6.85  1.57
# 7    Y6  2014-07  1,135  1.9900  0.42  2.39  10.66   54      3.13  2.51
# 8    Y7  2013-07  1,133  1.2500  0.36  3.11   9.90   44      3.77  3.20
# 9    Y8  2012-07  1,133  1.5900  0.36  2.16   9.69   39      3.21  1.89
# 10   Y9  2011-07  1,149  1.5500  0.33  1.57   7.26   28      2.70  1.29
# 11  Y10  2010-07  1,121  1.2200  0.32  1.75   6.63   24      3.04  1.64
#
#       P/E   EPS  EPS GR EPS GR 5Y avg EPS GR 10Y avg    DY   DPS Div Payout
# 2   13.33  0.09    7.36         14.22          34.74  3.33  0.04       44.3
# 3   18.67  0.09  -15.42         17.17           4.16  2.38  0.04       59.5
# 4   22.00  0.10   30.68         24.32           4.67  1.82  0.04       45.1
# 5   16.50  0.08  -21.62         26.27          10.20  3.03  0.04       44.9
# 6   63.50  0.10  109.04         35.45              —  0.47  0.03       25.9
# 7   39.80  0.05   21.92         58.95              —  0.50  0.01       17.6
# 8   31.25  0.04   13.76         -7.40              —  0.80  0.01       93.1
# 9   53.00  0.03   41.26        -11.87              —  1.26  0.02       56.3
# 10  77.50  0.02   11.32         -3.82              —  1.29  0.02       20.7
# 11  61.00  0.02  365.28             —              —  0.00     —      171.8
#    Revenue Revenue GR Revenue GR 5Y avg Revenue GR 10Y avg Operating CF  \
# 2    3,978      -2.71             18.33              18.56          224
# 3    4,089      24.62             28.57              14.72          217
# 4    3,281      50.82             22.24              11.81           77
# 5    2,176      12.33             16.20              12.36          136
# 6    1,937      12.93             19.34                  —           56
# 7    1,715      47.36             18.80                  —           46
# 8    1,164      -3.17              2.36                  —           20
# 9    1,202      17.06              2.26                  —           34
# 10   1,027      28.33              8.65                  —           94
# 11     800      10.39                 —                  —           49
#
#    Operating CF GR   D/E
# 2             3.42  0.05
# 3           182.17  0.07
# 4           -43.38  0.11
# 5           140.60  0.11
# 6            21.75  0.16
# 7           135.78  0.27
# 8           -42.35  0.31
# 9           -63.82  0.08
# 10           92.22  0.08
# 11          -11.37  0.10
# ----- Plot Graphs -----

# %%
val1, val2, fig1, fig2, fig3 = show_tables(2836)
# Out:
# ----- Stock Details for 2836: CARLSBERG BREWERY MALAYSIA BERHAD -----
# Empty DataFrame
# Columns: [name, category, Annual, nMerge, nSplit, NTA, current_price, 52w low, 52w high, market cap, intrinsic, price_A, price_B]
# Index: []
# Empty DataFrame
# Columns: [code, nYear, price, ROI, ROI avg, ROI std, ROE avg, ROE std, EPS GR avg, EPS GR std, EPS, EPS avg, EPS std, NPM avg, NPM std, P/E, P/E mid, P/E avg, P/E std]
# Index: []
# Empty DataFrame
# Columns: [DPS, DPS avg, DPS std, DPayout avg, DPayout std, DY avg, DY std]
# Index: []
#                                  name                      category  \
# 34  CARLSBERG BREWERY MALAYSIA BERHAD  Consumer Products & Services
#
#         Annual  nMerge  nSplit   NTA  current_price  52w low  52w high  \
# 34  2018-12-31       0       0  0.46           29.3    19.22     29.38
#
#    market cap
# 34   8,958.4M
#     code  nYear  price   ROI  ROI avg  ROI std  ROE avg  ROE std  EPS GR avg  \
# 34  2836     10  19.68  4.61     5.48     0.74    60.49    36.76       15.63
#
#     EPS GR std    EPS  EPS avg  EPS std  NPM avg  NPM std    P/E  P/E mid  \
# 34       22.38  90.65    61.55     16.9    11.93     1.95  21.71     18.1
#
#     P/E avg  P/E std
# 34    18.57      2.4
#       DPS  DPS avg  DPS std  DPayout avg  DPayout std  DY avg  DY std
# 34  100.0    67.95    19.09       110.33        13.36    6.09    1.44
# ----- Past 10 Year Financials -----
#    Year    EPS    DY    P/E    Price     DPS       ROE      EPS GR   ROI  \
# 3    Y1  90.65  5.08  21.71  19.6800  100.00  153.64 %    25.31%    4.61
# 4    Y2  72.34  5.69  21.15  15.3000   87.00   70.92 %     7.91%    4.73
# 5    Y3  67.04  5.17  20.76  13.9200   72.00   62.08 %    -5.07%    4.82
# 6    Y4  70.62  6.15  16.57  11.7000   72.00   63.05 %     2.05%    6.04
# 7    Y5  69.20  6.05  16.96  11.7400   71.00   64.08 %    15.03%    5.89
# 8    Y6  60.16  5.01  20.25  12.1800   61.00   64.68 %    -4.02%    4.94
# 9    Y7  62.68  5.03  19.98  12.5200   63.00   62.68 %    15.33%    5.01
# 10   Y8  54.35  8.49  15.71   8.5400   72.50   26.38 %    24.71%    6.36
# 11   Y9  43.58  9.18  14.50   6.3200   58.00   22.58 %    75.02%    6.90
# 12  Y10  24.90  5.07  18.09   4.5400   23.00   14.85 %         -    5.53
#
#        NOSH  Year End       NP NP Margin Div Payout      Div
# 3   305,748  31/12/18  277,154   14.47 %   110.32 %  305,748
# 4   305,748  31/12/17  221,165   13.14 %   120.27 %  266,000
# 5   305,748  31/12/16  204,978   12.54 %   107.40 %  220,138
# 6   305,739  31/12/15  215,913   13.27 %   101.95 %  220,132
# 7   305,748  31/12/14  211,582   13.27 %   102.60 %  217,081
# 8   305,748  31/12/13  183,925   12.00 %   101.40 %  186,506
# 9   305,748  31/12/12  191,632   12.23 %   100.52 %  192,621
# 10  305,722  31/12/11  166,160   11.24 %   133.39 %  221,648
# 11  305,741  31/12/10  133,242    9.80 %   133.09 %  177,329
# 12  303,365  31/12/09   76,142    7.34 %    91.64 %   69,774
# ----- Plot Graphs -----

# %%
import numpy as np, pandas as pd, re, time
from datetime import datetime
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.common.exceptions import TimeoutException
from time import time
from tqdm import tqdm
from glob import glob
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set()

chromedriver = '../selenium_driver/bin/chromedriver'
out_dir = 'result_2020-04-04/'

stock_code = pd.read_csv(out_dir+'stock_code_table.csv')
data1 = pd.read_csv(out_dir+'klse_screener_52week_price.csv')
data2 = pd.read_csv(out_dir+'klse_morningstar_merge_split.csv', parse_dates=['split_date'])
data2['code'] = data2['code'].astype(str).apply(lambda x: x.zfill(4))
data3 = pd.read_csv(out_dir+'klse_10yr_data.csv')
data3['code'] = data3['code'].astype(str).apply(lambda x: x.zfill(4))
data4 = pd.read_csv(out_dir+'klse_stock_stage_4.csv')
data4['code'] = data4['code'].astype(str).apply(lambda x: x.zfill(4))
data5 = pd.read_csv(out_dir+'klse_stock_intrinsic.csv')
data5['code'] = data5['code'].astype(str).apply(lambda x: x.zfill(4))
data6 = pd.read_csv(out_dir+'klse_stock_dividend_yield.csv')
data6['code'] = data6['code'].astype(str).apply(lambda x: x.zfill(4))

def show_tables(input_code):
    symbol = ['—','\xa0-\xa0']
    temp1 = data5[data5.code == str(input_code)]
    temp = temp1.columns.tolist()
    temp1_1 = temp1[temp[1:8]+temp[14:18]]
    temp1_2 = temp1[temp[:1]+temp[8:14]+temp[18:]]
    if len(temp1) == 0:
        temp4 = data6[data6.code == str(input_code)]
        temp = temp4.columns.tolist()
        temp4_1 = temp4[temp[1:8]+temp[14:18]]
        temp4_2 = temp4[temp[:1]+temp[8:14]+temp[18:]]
    temp2 = data3[data3.code == str(input_code)] # the 10 years data
    if len(temp2) == 0:
        print('<<<  This Stock did not pass Stage 1 filter.  >>>')
        return None, None, None
    temp3 = temp2.T.reset_index()
    temp3.columns = ['Year'] + temp3.iloc[1].tolist()[1:]
    temp3.drop(index=[0,1], inplace=True)
    temp_show = temp3.copy()
    for cols in ['NP','OCF','Revenue','Shares']:
        temp3[cols] = temp3[cols].apply(lambda x: int(x.replace(',','')) if x not in symbol else 0)
    for cols in ['D/E','DPS','Div Payout','EPS','EPS GR','EPS GR 10Y avg','EPS GR 5Y avg','NP Margin','NTA',
                 'OCF GR','Price','ROE','Revenue GR','Revenue GR 10Y avg','Revenue GR 5Y avg']:
        temp3[cols] = temp3[cols].apply(lambda x: float(x.replace(',','')) if x not in symbol else 0.0)
    temp_np = temp3['NP'].tolist()
    temp_shares = temp3['Shares'].tolist()
    temp_price = temp3['Price'].tolist()
    temp3['ROI'] = temp3.apply(lambda x: np.around(x['NP']/(x['Shares']*x['Price'])*100, 2) if x['Price'] != 0 else 0.0, axis=1)
    temp_show['ROI'] = temp3['ROI']
    temp3['EY'] = temp3.apply(lambda x: np.around(x['EPS']/x['Price']*100, 2) if x['Price'] != 0 else 0.0, axis=1)
    temp_show['EY'] = temp3['EY']
    temp3['P/E'] = temp3.apply(lambda x: np.around(x['Price']/x['EPS'], 2) if x['EPS'] != 0 else 0.0, axis=1)
    temp_show['P/E'] = temp3['P/E']
    temp3['DY'] = temp3.apply(lambda x: np.around(x['DPS']/x['Price']*100, 2) if x['Price'] != 0 else 0.0, axis=1)
    temp_show['DY'] = temp3['DY']
    temp = temp_show.columns.tolist()
    col_list = [temp[0],temp[-5],temp[-6],temp[13],temp[10],temp[-4],temp[14]]+temp[8:10]+temp[-3:-1]+temp[4:6]+[temp[7],temp[6]]+\
               temp[-1:]+temp[2:4]+[temp[15],temp[16],temp[18],temp[17]]+temp[11:13]+temp[1:2]
    temp_show = temp_show[col_list]
    
    try:
        if len(temp1) != 0:
            title = temp1.name.values[0]
        else:
            title = temp4.name.values[0]
    except:
        title = ''
        
    print('----- Stock Details for '+str(input_code)+': '+title+' -----')
    if len(temp1) != 0:
        display(temp1_1)
        display(temp1_2.iloc[:, :18])
        display(temp1_2.iloc[:, 18:33])
        display(temp1_2.iloc[:, 33:])
    else:
        if len(temp4_1) != 0:
            display(temp4_1)
            display(temp4_2.iloc[:, :19])
            display(temp4_2.iloc[:, 19:33])
            display(temp4_2.iloc[:, 33:])
        else:
            print('<<<  This Stock did not pass Stage 4 filter.  >>>')
        
    print('\n----- Past 10 Year Financials -----')
    display(temp_show.iloc[:,:18])
    display(temp_show.iloc[:,18:])
    
    print('\n----- Plot Graphs -----')
    fig1, fig2, fig3 = plot_tables(temp3[::-1])
#     fig1, fig2, fig3 = None
    if len(temp1) != 0:
        return temp1, temp3, fig1, fig2, fig3
    else:
        return temp4, temp3, fig1, fig2, fig3

def add_trendline(x, y):
    z = np.polyfit(x, y, 1)
    return z, np.poly1d(z)(x)
    
def plot_tables(table):
    nYear = len([x for x in table['NP'].tolist() if x != 0])
    
    fig1, ax = plt.subplots(1, 2, figsize=(20,6))
    fig1.patch.set_facecolor('white')
    ax0 = ax[0].twinx()
    ax[0].bar(np.arange(10)-0.2, table['NP'], color='black', width=0.4, alpha=0.7)
    ax0.bar(np.arange(10)+0.2, table['NP Margin'], color='red', width=0.4, alpha=0.7)
    ax[0].set_xticks(np.arange(0,10,1))
    ax[0].set_xticklabels(table.Year)
    ax[0].set_xlabel('Year')
    ax[0].set_ylabel('Net Profit')
    ax0.set_ylabel('NP Margin (%)')
    ax[0].set_title('Net Profit vs NP Margin')
    coeff1, line1 = add_trendline(np.arange(nYear)-0.2, table['NP'][-nYear:])
    coeff2, line2 = add_trendline(np.arange(nYear)+0.2, table['NP Margin'][-nYear:])
    ax[0].legend([str(np.around(coeff1[0],2))] ,loc="upper left")
    ax0.legend([str(np.around(coeff2[0],2))] ,loc="upper left", bbox_to_anchor=(0, 0.94))
    ax[0].plot(np.arange((10-nYear),10)-0.2, line1, '--', color='black', linewidth=3)
    ax0.plot(np.arange((10-nYear),10)+0.2, line2, '--', color='red', linewidth=3)

    
    ax0 = ax[1].twinx()
    ax[1].bar(np.arange(10)-0.3, table['Revenue'], color='black', width=0.3, alpha=0.7)
    ax0.bar(np.arange(10), table['OCF'], color='red', width=0.3, alpha=0.7)
    ax0.bar(np.arange(10)+0.3, table['NP'], color='blue', width=0.3, alpha=0.7)
    ax[1].set_xticks(np.arange(0,10,1))
    ax[1].set_xticklabels(table.Year)
    ax[1].set_xlabel('Year')
    ax[1].set_ylabel('MYR Mil')
    ax[1].set_title('Revenue vs Operating Cash Flow vs Net Profit')
    coeff1, line1 = add_trendline(np.arange(nYear)-0.3, table['Revenue'][-nYear:])
    coeff2, line2 = add_trendline(np.arange(nYear), table['OCF'][-nYear:])
    coeff3, line3 = add_trendline(np.arange(nYear)+0.3, table['NP'][-nYear:])
    ax[1].legend(['Revenue : '+str(np.around(coeff1[0],2))], loc="upper left")
    ax0.legend(['OCF : '+str(np.around(coeff2[0],2)),
                'NP : '+str(np.around(coeff3[0],2))], loc="upper left",bbox_to_anchor=(0, 0.94))
    ax[1].plot(np.arange((10-nYear),10)-0.3, line1, '--', color='black', linewidth=3)
    ax0.plot(np.arange((10-nYear),10), line2, '--', color='red', linewidth=3)
    ax0.plot(np.arange((10-nYear),10)+0.3, line3, '--', color='blue', linewidth=3)
    
    
    fig2, ax = plt.subplots(1, 2, figsize=(20,6))
    fig2.patch.set_facecolor('white')
    ax0 = ax[0].twinx()
    ax[0].bar(np.arange(10)-0.2, table['EY'], color='black', width=0.4, alpha=0.7)
    ax0.bar(np.arange(10)+0.2, table['DY'], color='red', width=0.4, alpha=0.7)
    ax[0].set_xticks(np.arange(0,10,1))
    ax[0].set_xticklabels(table.Year)
    ax[0].set_xlabel('Year')
    ax[0].set_ylabel('Earning Yield (%)')
    ax0.set_ylabel('Dividend Yield (%)')
    ax[0].set_title('Earning Yield vs Dividend Yield') 
    coeff1, line1 = add_trendline(np.arange(nYear)-0.2, table['EY'][-nYear:])
    coeff2, line2 = add_trendline(np.arange(nYear)+0.2, table['DY'][-nYear:])
    ax[0].legend([str(np.around(coeff1[0],2))] ,loc="upper left")
    ax0.legend([str(np.around(coeff2[0],2))] ,loc="upper left", bbox_to_anchor=(0, 0.94))
    ax[0].plot(np.arange((10-nYear),10)-0.2, line1, '--', color='black', linewidth=3)
    ax0.plot(np.arange((10-nYear),10)+0.2, line2, '--', color='red', linewidth=3)
    
    
    ax[1].bar(np.arange(10)-0.2, table['EPS'], color='black', width=0.4, alpha=0.7)
    ax[1].bar(np.arange(10)+0.2, table['DPS'], color='red', width=0.4, alpha=0.7)
    ax[1].set_xticks(np.arange(0,10,1))
    ax[1].set_xticklabels(table.Year)
    ax[1].set_xlabel('Year')
    ax[1].set_ylabel('Amount per Share (Sen)')
    ax[1].set_title('Earning per Share vs Dividend per Share')
    coeff1, line1 = add_trendline(np.arange(nYear)-0.2, table['EPS'][-nYear:])
    coeff2, line2 = add_trendline(np.arange(nYear)+0.2, table['DPS'][-nYear:])
    ax[1].legend(['EPS : '+str(np.around(coeff1[0],2)),
                  'DPS : '+str(np.around(coeff2[0],2))],loc="upper left")
    ax[1].plot(np.arange((10-nYear),10)-0.2, line1, '--', color='black', linewidth=3)
    ax[1].plot(np.arange((10-nYear),10)+0.2, line2, '--', color='red', linewidth=3)
    
    
    fig3, ax = plt.subplots(1, 2, figsize=(20,6))
    fig3.patch.set_facecolor('white')
    ax0 = ax[0].twinx()
    ax[0].bar(np.arange(10)-0.2, table['Price'], color='black', width=0.4, alpha=0.7)
    ax0.bar(np.arange(10)+0.2, table['P/E'], color='red', width=0.4, alpha=0.7)
    ax[0].set_xticks(np.arange(0,10,1))
    ax[0].set_xticklabels(table.Year)
    ax[0].set_xlabel('Year')
    ax[0].set_ylabel('Share Price (RM)')
    ax0.set_ylabel('Ratio')
    ax[0].set_title('Price vs P/E Ratio')
    coeff1, line1 = add_trendline(np.arange(nYear)-0.2, table['Price'][-nYear:])
    coeff2, line2 = add_trendline(np.arange(nYear)+0.2, table['P/E'][-nYear:])
    ax[0].legend([str(np.around(coeff1[0],2))] ,loc="upper left")
    ax0.legend([str(np.around(coeff2[0],2))] ,loc="upper left", bbox_to_anchor=(0, 0.94))
    ax[0].plot(np.arange((10-nYear),10)-0.2, line1, '--', color='black', linewidth=3)
    ax0.plot(np.arange((10-nYear),10)+0.2, line2, '--', color='red', linewidth=3)
    
    
    ax[1].bar(np.arange(10)-0.2, table['ROI'], color='black', width=0.4, alpha=0.7)
    ax[1].bar(np.arange(10)+0.2, table['ROE'], color='red', width=0.4, alpha=0.7)
    ax[1].set_xticks(np.arange(0,10,1))
    ax[1].set_xticklabels(table.Year)
    ax[1].set_xlabel('Year')
    ax[1].set_ylabel('Percentage (%)')
    ax[1].set_title('Return on Investment vs Return on Equity')
    coeff1, line1 = add_trendline(np.arange(nYear)-0.2, table['ROI'][-nYear:])
    coeff2, line2 = add_trendline(np.arange(nYear)+0.2, table['ROE'][-nYear:])
    ax[1].legend(['ROI : '+str(np.around(coeff1[0],2)),
                  'ROE : '+str(np.around(coeff2[0],2))],loc="upper left")
    ax[1].plot(np.arange((10-nYear),10)-0.2, line1, '--', color='black', linewidth=3)
    ax[1].plot(np.arange((10-nYear),10)+0.2, line2, '--', color='red', linewidth=3)
    
    
    return fig1, fig2, fig3

# %%
def plot_tables(table):
    nYear = len([x for x in table['NP'].tolist() if x != 0])
    fig2, ax = plt.subplots(1, 2, figsize=(20,6))
    fig2.patch.set_facecolor('white')
    ax0 = ax[0].twinx()
    ax[0].bar(np.arange(10)-0.2, table['EY'], color='black', width=0.4, alpha=0.7)
    ax0.bar(np.arange(10)+0.2, table['DY'], color='red', width=0.4, alpha=0.7)
    ax[0].set_xticks(np.arange(0,10,1))
    ax[0].set_xticklabels(table.Year)
    ax[0].set_xlabel('Year')
    ax[0].set_ylabel('Earning Yield (%)')
    ax0.set_ylabel('Dividend Yield (%)')
    ax[0].set_title('Earning Yield vs Dividend Yield') 
    coeff1, line1 = add_trendline(np.arange(nYear)-0.2, table['EY'][-nYear:])
    coeff2, line2 = add_trendline(np.arange(nYear)+0.2, table['DY'][-nYear:])
    ax[0].legend([str(np.around(coeff1[0],2))] ,loc="upper left")
    ax0.legend([str(np.around(coeff2[0],2))] ,loc="upper left", bbox_to_anchor=(0, 0.94))
    ax[0].plot(np.arange((10-nYear),10)-0.2, line1, '--', color='black', linewidth=3)
    ax0.plot(np.arange((10-nYear),10)+0.2, line2, '--', color='red', linewidth=3)
    
    
    ax[1].bar(np.arange(10)-0.2, table['EPS'], color='black', width=0.4, alpha=0.7)
    ax[1].bar(np.arange(10)+0.2, table['DPS'], color='red', width=0.4, alpha=0.7)
    ax[1].set_xticks(np.arange(0,10,1))
    ax[1].set_xticklabels(table.Year)
    ax[1].set_xlabel('Year')
    ax[1].set_ylabel('Amount per Share (Sen)')
    ax[1].set_title('Earning per Share vs Dividend per Share')
    coeff1, line1 = add_trendline(np.arange(nYear)-0.2, table['EPS'][-nYear:])
    coeff2, line2 = add_trendline(np.arange(nYear)+0.2, table['DPS'][-nYear:])
    ax[1].legend(['EPS : '+str(np.around(coeff1[0],2)),
                  'DPS : '+str(np.around(coeff2[0],2))],loc="upper left")
    ax[1].plot(np.arange((10-nYear),10)-0.2, line1, '--', color='black', linewidth=3)
    ax[1].plot(np.arange((10-nYear),10)+0.2, line2, '--', color='red', linewidth=3)
    
    fig1, fig3 = None,None

    return fig1, fig2, fig3
val1, val2, fig1, fig2, fig3 = show_tables(5271)
# Out:
# ----- Stock Details for 5271: PECCA GROUP BERHAD -----
#                   name                        category  price    NTA  52w low  \
# 90  PECCA GROUP BERHAD  Industrial Products & Services  0.745  0.913    0.675
#
#     52w high market cap      Annual  nYear  nMerge  nSplit
# 90       1.3     140.1M  2019-06-01      5       0       0
#     code   ROE  P/E  EPS     EY  DPS    DY   ROI  ROI avg  ROI std  NPM avg  \
# 90  5271  9.42  9.0  8.6  11.54  6.0  8.05  7.96     6.34     1.07    11.82
#
#     NPM std  EPS avg  EPS std  EPS GR avg  EPS GR std  EPS GR 5Y avg  \
# 90     1.58     0.09     0.02       -2.22       38.55            0.0
#
#     EPS GR 10Y avg
# 90             0.0
#     EY avg  EY std  ROE avg  ROE std  P/E mid  P/E avg  P/E std  DPS avg  \
# 90    6.47    1.02    12.85     6.76    10.06     12.7     6.79     0.03
#
#     DPS std  DPayout avg  DPayout std  DY avg  DY std  D/E avg  D/E std
# 90     0.02        66.97        23.92    3.66    1.86     0.16      0.0
#     OCF GR avg  OCF GR std  Revenue GR avg  Revenue GR std  Revenue GR 5Y avg  \
# 90       24.63       74.73            0.77            9.36                0.0
#
#     Revenue GR 10Y avg  intrinsic  price_A  price_B
# 90                 0.0       6.65     4.99     0.88
# ----- Past 10 Year Financials -----
#    Year Year End Shares   Price   NTA   ROI    ROE  NP NP Margin    EY    P/E  \
# 2    Y1  2019-06    184  1.1600  0.91  7.96  10.22  17     12.65  7.76  12.89
# 3    Y2  2018-06    186  0.8700  0.88  6.18   6.32  10      9.07  6.90  14.50
# 4    Y3  2017-06    188  1.6100  0.86  4.96   9.16  15     12.02  4.97  20.12
# 5    Y4  2016-06    150  1.6000     —  6.25  12.82  15     11.51  6.25  16.00
# 6    Y5  2015-06    140  0.0000     —  0.00  25.71  18     13.85  0.00   0.00
# 7    Y6  2014-06      —       —     —  0.00      —   —         —  0.00   0.00
# 8    Y7  2013-06      —       —     —  0.00      —   —         —  0.00   0.00
# 9    Y8  2012-06      —       —     —  0.00      —   —         —  0.00   0.00
# 10   Y9  2011-06      —       —     —  0.00      —   —         —  0.00   0.00
# 11  Y10  2010-06      —       —     —  0.00      —   —         —  0.00   0.00
#
#      EPS  EPS GR EPS GR 5Y avg EPS GR 10Y avg    DY   DPS Div Payout
# 2   0.09   64.25             —              —  5.17  0.06       33.8
# 3   0.06  -29.45             —              —  5.75  0.05       89.3
# 4   0.08  -19.23             —              —  2.48  0.04       77.8
# 5   0.10  -24.45             —              —  1.25  0.02          —
# 6   0.13       —             —              —  0.00     —          —
# 7      —       —             —              —  0.00     —          —
# 8      —       —             —              —  0.00     —          —
# 9      —       —             —              —  0.00     —          —
# 10     —       —             —              —  0.00     —          —
# 11     —       —             —              —  0.00     —          —
#    Revenue Revenue GR Revenue GR 5Y avg Revenue GR 10Y avg OCF  OCF GR   D/E
# 2      131      16.60                 —                  —  12  -29.97     —
# 3      113      -7.77                 —                  —  17   13.79     —
# 4      122      -3.27                 —                  —  15  -35.10     —
# 5      126      -2.50                 —                  —  23  149.81     —
# 6      130          —                 —                  —   9       —  0.16
# 7        —          —                 —                  —   —       —     —
# 8        —          —                 —                  —   —       —     —
# 9        —          —                 —                  —   —       —     —
# 10       —          —                 —                  —   —       —     —
# 11       —          —                 —                  —   —       —     —
# ----- Plot Graphs -----

# %%
np.arange((11-3), 11)
# Out:
# array([ 8,  9, 10])

# %%
# ax_2 = table.subplots(3,1)
# table_1 = pd.plotting.table(ax_2[2], val1.iloc[:,:16], loc='bottom', colWidths=[0.05]*len(val1.columns))
# table_1.auto_set_font_size(False)
# table_1.set_fontsize(12)
# table_1.scale(1.2, 2)

# table_2 = pd.plotting.table(axes, val1.iloc[:,16:], loc='center left', colWidths=[0.05]*len(val1.columns))
# table_2.auto_set_font_size(False)
# table_2.set_fontsize(12)
# table_2.scale(1.2, 2)

# table_3 = pd.plotting.table(axes, val2, loc='lower left', colWidths=[0.05]*len(val1.columns)) # where df is your data frame
# table_3.auto_set_font_size(False)
# table_3.set_fontsize(12)
# table_3.scale(1.2, 2)

# table.savefig('mytable.png', transparent=True)
