# %% [markdown]
# ## First Stage Filter
#
# - ROI avg >= 6.0%
# - ROE avg >= 6.0%
# - EPS GR avg >= 6.0%
# - nYear >= 5 years

# %%
val1, val2, table = show_tables(5172)
# Out:
# ----- Stock Details for 5172:  -----
# Empty DataFrame
# Columns: [name, category, Annual, nMerge, nSplit, NTA, current_price, 52w low, 52w high, market cap, intrinsic, price_A, price_B]
# Index: []
# Empty DataFrame
# Columns: [code, nYear, price, ROI, ROI avg, ROI std, ROE avg, ROE std, EPS GR avg, EPS GR std, EPS, EPS avg, EPS std, NPM avg, NPM std, P/E, P/E mid, P/E avg, P/E std]
# Index: []
# Empty DataFrame
# Columns: [DPS, DPS avg, DPS std, DPayout avg, DPayout std, DY avg, DY std]
# Index: []
# Empty DataFrame
# Columns: [name, category, Annual, nMerge, nSplit, NTA, current_price, 52w low, 52w high, market cap]
# Index: []
# Empty DataFrame
# Columns: [code, nYear, price, ROI, ROI avg, ROI std, ROE avg, ROE std, EPS GR avg, EPS GR std, EPS, EPS avg, EPS std, NPM avg, NPM std, P/E, P/E mid, P/E avg, P/E std]
# Index: []
# Empty DataFrame
# Columns: [DPS, DPS avg, DPS std, DPayout avg, DPayout std, DY avg, DY std]
# Index: []
# ----- Past 10 Year Financials -----
#    Year    DY    P/E   Price   DPS        EPS GR     EPS        ROE     ROI  \
# 3    Y1  0.00  -0.80  0.0850  0.00     -34.31%    -11.04  -144.26 % -125.09
# 4    Y2  0.00  -1.30  0.1050  0.00      68.11%     -8.22    -0.47 %  -76.84
# 5    Y3  0.00  -0.19  0.0500  0.00     -34.97%    -25.78    -0.95 % -515.75
# 6    Y4  0.00  -0.37  0.0700  0.00     -83.30%    -19.10   -33.77 % -272.92
# 7    Y5  0.00  -1.25  0.1300  0.00      40.35%    -10.42   -13.78 %  -80.22
# 8    Y6  0.00  -0.63  0.1100  0.00    -222.92%    -17.47   -23.82 % -158.74
# 9    Y7  0.00  -2.77  0.1500  0.00    -166.38%     -5.41    -6.20 %  -36.05
# 10   Y8  0.00   3.31  0.2700  0.00     -52.59%      8.15     9.71 %   30.18
# 11   Y9  4.00   2.33  0.4000  1.60     -24.87%     17.19     0.23 %   42.98
# 12  Y10  0.00   0.00  0.0000  0.00           -     22.88     0.12 %     inf
#
#        NOSH Div Payout    Div       NP  Year End NP Margin
# 3   380,952        - %      -  -40,504  31/12/18  -26.53 %
# 4   293,040        - %      -  -23,642  31/12/17  -12.53 %
# 5   266,332        - %      -  -68,680  31/12/16  -36.65 %
# 6   266,400        - %      -  -50,895  31/12/15  -25.52 %
# 7   265,844        - %      -  -27,723  31/12/14  -13.93 %
# 8   266,477        - %      -  -46,530  31/12/13  -25.09 %
# 9   266,428        - %      -  -14,409  31/12/12   -5.35 %
# 10  266,555        - %      -   21,717  31/12/11    6.78 %
# 11  240,046     9.31 %  3,840   41,264  31/12/10   13.15 %
# 12  180,476        - %      -   41,293  31/12/09   15.46 %
# ----- Plot Graphs -----

# %%
val1, val2, table = show_tables(9296)
# Out:
# ----- Stock Details for 9296: RCE CAPITAL BERHAD -----
#                   name            category      Annual  nMerge  nSplit  NTA  \
# 13  RCE CAPITAL BERHAD  Financial Services  2019-03-31       1       0  1.8
#
#     current_price  52w low  52w high market cap  intrinsic  price_A  price_B
# 13           1.66     1.44      1.81     614.0M       2.86     2.14     1.56
#     code  nYear  price    ROI  ROI avg  ROI std  ROE avg  ROE std  EPS GR avg  \
# 13  9296     10   1.63  17.15    17.56    12.72    12.99     7.84       133.0
#
#     EPS GR std    EPS  EPS avg  EPS std  NPM avg  NPM std   P/E  P/E mid  \
# 13      290.68  28.02    12.14    10.18    28.97    11.88  5.83    53.08
#
#     P/E avg  P/E std
# 13    18.66    29.58
#     DPS  DPS avg  DPS std  DPayout avg  DPayout std  DY avg  DY std
# 13  9.0     4.22     4.13       136.76       191.75    9.05    13.4
# ----- Past 10 Year Financials -----
#    Year      Div    EPS Div Payout       NP  Year End       NOSH NP Margin  \
# 3    Y1   30,758  28.02    32.20 %   95,533  31/03/19    341,756   36.38 %
# 4    Y2   23,937  26.03    26.99 %   88,681  31/03/18    341,970   36.06 %
# 5    Y3    9,901  23.92    12.54 %   78,949  31/03/17    330,054   35.35 %
# 6    Y4  179,868   3.08   454.55 %   39,571  31/03/16  1,284,772   24.37 %
# 7    Y5   17,719   2.27    66.08 %   26,816  31/03/15  1,181,321   27.60 %
# 8    Y6   17,355   0.27   555.56 %    3,124  31/03/14  1,157,036    9.61 %
# 9    Y7   17,564   0.83   180.72 %    9,719  31/03/13  1,170,963    5.79 %
# 10   Y8   11,739  12.95    11.58 %  101,355  31/03/12    782,664   44.09 %
# 11   Y9   11,731  13.33    11.25 %  104,257  31/03/11    782,123   38.67 %
# 12  Y10   13,238  10.72    16.32 %   81,094  31/03/10    756,473   31.73 %
#
#       ROI      ROE     DY       EPS GR    DPS   Price     P/E
# 3   17.15  16.35 %   5.52      7.65%     9.00  1.6300    5.83
# 4   21.08  17.06 %   5.69      8.82%     7.00  1.2300    4.74
# 5   13.44  18.26 %   1.69    676.62%     3.00  1.7800    7.44
# 6   10.81   8.80 %  49.12     35.68%    14.00  0.2850    9.25
# 7    7.21   5.16 %   4.76    740.74%     1.50  0.3150   13.88
# 8    0.96   0.49 %   5.36    -67.47%     1.50  0.2800  103.70
# 9    3.07   1.48 %   5.56    -93.59%     1.50  0.2700   32.53
# 10  40.47  19.04 %   4.69     -2.85%     1.50  0.3200    2.47
# 11  37.03  23.39 %   4.17     24.35%     1.50  0.3600    2.70
# 12  24.36  19.85 %   3.98          -     1.75  0.4400    4.10
# ----- Plot Graphs -----

# %%
val1, val2, table = show_tables(2836)
# Out:
# ----- Stock Details for 2836: CARLSBERG BREWERY MALAYSIA BERHAD -----
# Empty DataFrame
# Columns: [name, category, Annual, nMerge, nSplit, NTA, current_price, 52w low, 52w high, market cap, intrinsic, price_A, price_B]
# Index: []
# Empty DataFrame
# Columns: [code, nYear, price, ROI, ROI avg, ROI std, ROE avg, ROE std, EPS GR avg, EPS GR std, EPS, EPS avg, EPS std, NPM avg, NPM std, P/E, P/E mid, P/E avg, P/E std]
# Index: []
# Empty DataFrame
# Columns: [DPS, DPS avg, DPS std, DPayout avg, DPayout std, DY avg, DY std]
# Index: []
#                                  name                      category  \
# 34  CARLSBERG BREWERY MALAYSIA BERHAD  Consumer Products & Services
#
#         Annual  nMerge  nSplit   NTA  current_price  52w low  52w high  \
# 34  2018-12-31       0       0  0.46           29.3    19.22     29.38
#
#    market cap
# 34   8,958.4M
#     code  nYear  price   ROI  ROI avg  ROI std  ROE avg  ROE std  EPS GR avg  \
# 34  2836     10  19.68  4.61     5.48     0.74    60.49    36.76       15.63
#
#     EPS GR std    EPS  EPS avg  EPS std  NPM avg  NPM std    P/E  P/E mid  \
# 34       22.38  90.65    61.55     16.9    11.93     1.95  21.71     18.1
#
#     P/E avg  P/E std
# 34    18.57      2.4
#       DPS  DPS avg  DPS std  DPayout avg  DPayout std  DY avg  DY std
# 34  100.0    67.95    19.09       110.33        13.36    6.09    1.44
# ----- Past 10 Year Financials -----
#    Year    EPS    DY    P/E    Price     DPS       ROE      EPS GR   ROI  \
# 3    Y1  90.65  5.08  21.71  19.6800  100.00  153.64 %    25.31%    4.61
# 4    Y2  72.34  5.69  21.15  15.3000   87.00   70.92 %     7.91%    4.73
# 5    Y3  67.04  5.17  20.76  13.9200   72.00   62.08 %    -5.07%    4.82
# 6    Y4  70.62  6.15  16.57  11.7000   72.00   63.05 %     2.05%    6.04
# 7    Y5  69.20  6.05  16.96  11.7400   71.00   64.08 %    15.03%    5.89
# 8    Y6  60.16  5.01  20.25  12.1800   61.00   64.68 %    -4.02%    4.94
# 9    Y7  62.68  5.03  19.98  12.5200   63.00   62.68 %    15.33%    5.01
# 10   Y8  54.35  8.49  15.71   8.5400   72.50   26.38 %    24.71%    6.36
# 11   Y9  43.58  9.18  14.50   6.3200   58.00   22.58 %    75.02%    6.90
# 12  Y10  24.90  5.07  18.09   4.5400   23.00   14.85 %         -    5.53
#
#        NOSH  Year End       NP NP Margin Div Payout      Div
# 3   305,748  31/12/18  277,154   14.47 %   110.32 %  305,748
# 4   305,748  31/12/17  221,165   13.14 %   120.27 %  266,000
# 5   305,748  31/12/16  204,978   12.54 %   107.40 %  220,138
# 6   305,739  31/12/15  215,913   13.27 %   101.95 %  220,132
# 7   305,748  31/12/14  211,582   13.27 %   102.60 %  217,081
# 8   305,748  31/12/13  183,925   12.00 %   101.40 %  186,506
# 9   305,748  31/12/12  191,632   12.23 %   100.52 %  192,621
# 10  305,722  31/12/11  166,160   11.24 %   133.39 %  221,648
# 11  305,741  31/12/10  133,242    9.80 %   133.09 %  177,329
# 12  303,365  31/12/09   76,142    7.34 %    91.64 %   69,774
# ----- Plot Graphs -----

# %%
val1, val2, table = show_tables(104)
# Out:
# This Stock did not pass 1st stage filter.

# %%
import numpy as np, pandas as pd, re, time
from datetime import datetime
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.common.exceptions import TimeoutException
from time import time
from tqdm import tqdm
from glob import glob
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set()

chromedriver = '../selenium_driver/bin/chromedriver'

stock_code = pd.read_csv('personal/stock_code_table.csv')
data1 = pd.read_csv('personal/klse_screener_52week_price.csv')
data2 = pd.read_csv('personal/klse_morningstar_merge_split.csv', parse_dates=['split_date'])
data2['code'] = data2['code'].astype(str).apply(lambda x: x.zfill(4))
data3 = pd.read_csv('personal/klse_investor_10yr.csv')
data3['code'] = data3['code'].astype(str).apply(lambda x: x.zfill(4))
data4 = pd.read_csv('personal/klse_stock_stage_4.csv')
data4['code'] = data4['code'].astype(str).apply(lambda x: x.zfill(4))
data5 = pd.read_csv('personal/klse_stock_intrinsic.csv')
data5['code'] = data5['code'].astype(str).apply(lambda x: x.zfill(4))
data6 = pd.read_csv('personal/klse_stock_dividend_yield.csv')
data6['code'] = data6['code'].astype(str).apply(lambda x: x.zfill(4))

def show_tables(input_code):
    symbol = ['  -  ', '-', '- %', '\xa0-\xa0', '\xa0-\xa0 %', '-\xa0 %', 'nan']
    temp1 = data5[data5.code == str(input_code)]
    temp = temp1.columns.tolist()
    col_1 = [temp[-4],temp[29],temp[28]]+temp[26:28]+[temp[-5]]+temp[-9:-5]+temp[-3:]
    col_2 = temp[:2]+[temp[25]]+temp[2:9]+temp[15:18]+temp[9:15]+temp[18:25]
    # temp1 = temp1[col_1 + col_2]
    temp1_1 = temp1[col_1]
    temp1_2 = temp1[col_2]
    if len(temp1) == 0:
        temp4 = data6[data6.code == str(input_code)]
        temp = temp4.columns.tolist()
        col_1 = [temp[-1],temp[29],temp[28]]+temp[26:28]+[temp[-2]]+temp[-6:-2]
        col_2 = temp[:2]+[temp[25]]+temp[2:9]+temp[15:18]+temp[9:15]+temp[18:25]
        # temp4 = temp4[col_1 + col_2]
        temp4_1 = temp4[col_1]
        temp4_2 = temp4[col_2]
    temp2 = data3[data3.code == str(input_code)]
    if len(temp2) == 0:
        print('This Stock did not pass 1st stage filter.')
        return None, None, None
    temp3 = temp2.T.reset_index()
    temp3.columns = ['Year'] + temp3.iloc[2].tolist()[1:]
    temp3.drop(index=[0,1,2], inplace=True)
    temp_show = temp3.copy()
    for cols in ['NP','Div','NOSH']:
        temp3[cols] = temp3[cols].apply(lambda x: int(x.replace(',','')) if str(x).strip() not in symbol else 0)
    for cols in ['Div Payout','NP Margin','ROE', 'EPS GR']:
        temp3[cols] = temp3[cols].apply(lambda x: float(x.replace('%','').replace(',','')) if str(x).strip() not in symbol else 0.0)
    for cols in ['EPS','DPS','Price','P/E','DY']:
        temp3[cols] = temp3[cols].apply(lambda x: float(x) if str(x).strip() not in symbol else 0.0)
    temp3['ROI'] = np.around(temp3['NP']/(temp3['NOSH']*temp3['Price'])*100, 2)
    temp_show['ROI'] = temp3['ROI']
    temp_cols = temp_show.columns.tolist()
    temp_show = temp_show[temp_cols[:8]+temp_cols[-1:]+temp_cols[8:-1]]
    
    try:
        if len(temp1) != 0:
            title = temp1.name.values[0]
        else:
            title = temp4.name.values[0]
    except:
        title = ''
        
    print('----- Stock Details for '+str(input_code)+': '+title+' -----')
    display(temp1_1)
    display(temp1_2.iloc[:, :19])
    display(temp1_2.iloc[:, 19:])
    
    if len(temp1) == 0:
        display(temp4_1)
        display(temp4_2.iloc[:, :19])
        display(temp4_2.iloc[:, 19:])
        
    print('\n----- Past 10 Year Financials -----')
    display(temp_show)
    
    print('\n----- Plot Graphs -----')
    table, _ = plot_tables(temp3[::-1])
        
    if len(temp1) != 0:
        return temp1, temp3, table
    else:
        return temp4, temp3, table

def plot_tables(table):
    fig, ax = plt.subplots(3, 2, figsize=(20,20))
    fig.patch.set_facecolor('white')
    ax0 = ax[0,0].twinx()
    ax[0,0].bar(np.arange(10)-0.2, table['NP'], color='r', width=0.4)
    ax0.bar(np.arange(10)+0.2, table['NP Margin'], color='k', width=0.4)
    ax[0,0].set_xticks(np.arange(0,10,1))
    ax[0,0].set_xticklabels(table.Year)
    ax[0,0].set_xlabel('Year')
    ax[0,0].set_ylabel('Net Profit')
    ax0.set_ylabel('NP Margin (%)')
    ax[0,0].set_title('Net Profit vs NP Margin')

    ax[0,1].bar(np.arange(10)-0.2, table['NP'], color='r', width=0.4)
    ax[0,1].bar(np.arange(10)+0.2, table['Div'], color='k', width=0.4)
    ax[0,1].set_xticks(np.arange(0,10,1))
    ax[0,1].set_xticklabels(table.Year)
    ax[0,1].set_xlabel('Year')
#     ax[0,1].set_ylabel("Volume '000")
    ax[0,1].set_title('Net Profit vs Dividend')
    ax[0,1].legend(['NP','Div'],loc="upper right")
    
    ax0 = ax[1,0].twinx()
    ax[1,0].bar(np.arange(10)-0.2, table['Div Payout'], color='r', width=0.4)
    ax0.bar(np.arange(10)+0.2, table['DY'], color='k', width=0.4)
    ax[1,0].set_xticks(np.arange(0,10,1))
    ax[1,0].set_xticklabels(table.Year)
    ax[1,0].set_xlabel('Year')
    ax[1,0].set_ylabel('Divident Payout (%)')
    ax0.set_ylabel('Dividend Yield (%)')
    ax[1,0].set_title('Divident Payout vs Dividend Yield')
    # ax[1,0].legend(['Div Payout','Div Yield'],loc="upper right")   

    ax[1,1].bar(np.arange(10)-0.2, table['EPS'], color='r', width=0.4)
    ax[1,1].bar(np.arange(10)+0.2, table['DPS'], color='k', width=0.4)
    ax[1,1].set_xticks(np.arange(0,10,1))
    ax[1,1].set_xticklabels(table.Year)
    ax[1,1].set_xlabel('Year')
    ax[1,1].set_ylabel('Amount per Share (Sen)')
    ax[1,1].set_title('Earning per Share vs Dividend per Share')
    ax[1,1].legend(['EPS','DPS'],loc="upper right")

    ax0 = ax[2,0].twinx()
    ax[2,0].bar(np.arange(10)-0.2, table['Price'], color='r', width=0.4)
    ax0.bar(np.arange(10)+0.2, table['P/E'], color='k', width=0.4)
    ax[2,0].set_xticks(np.arange(0,10,1))
    ax[2,0].set_xticklabels(table.Year)
    ax[2,0].set_xlabel('Year')
    ax[2,0].set_ylabel('Share Price (RM)')
    ax0.set_ylabel('Ratio')
    ax[2,0].set_title('Price per Share vs P/E Ratio')
    
    ax[2,1].bar(np.arange(10)-0.2, table['ROI'], color='r', width=0.4)
    ax[2,1].bar(np.arange(10)+0.2, table['ROE'], color='k', width=0.4)
    ax[2,1].set_xticks(np.arange(0,10,1))
    ax[2,1].set_xticklabels(table.Year)
    ax[2,1].set_xlabel('Year')
    ax[2,1].set_ylabel('Percentage (%)')
    ax[2,1].set_title('Return on Investment vs Return on Equity')

    return fig, ax

# %%
# ax_2 = table.subplots(3,1)
# table_1 = pd.plotting.table(ax_2[2], val1.iloc[:,:16], loc='bottom', colWidths=[0.05]*len(val1.columns))
# table_1.auto_set_font_size(False)
# table_1.set_fontsize(12)
# table_1.scale(1.2, 2)

# table_2 = pd.plotting.table(axes, val1.iloc[:,16:], loc='center left', colWidths=[0.05]*len(val1.columns))
# table_2.auto_set_font_size(False)
# table_2.set_fontsize(12)
# table_2.scale(1.2, 2)

# table_3 = pd.plotting.table(axes, val2, loc='lower left', colWidths=[0.05]*len(val1.columns)) # where df is your data frame
# table_3.auto_set_font_size(False)
# table_3.set_fontsize(12)
# table_3.scale(1.2, 2)

# table.savefig('mytable.png', transparent=True)
